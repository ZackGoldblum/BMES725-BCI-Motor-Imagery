# %%
# http://bbci.de/competition/iv/desc_2a.pdf
# http://bbci.de/competition/iv/

# %%
import os
import numpy as np
import mne
raw_eeg = mne.io.read_raw_gdf(r'BCIC_IV_2a/A01E.gdf')
# print(raw_eeg.info)
# Out:
# Extracting EDF parameters from /Users/danieljthompson/Desktop/BMES 725/BMES725-BCI-Motor-Imagery/BCIC_IV_2a/A01E.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# /Users/danieljthompson/venv/lib/python3.8/site-packages/mne/io/edf/edf.py:1047: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# <ipython-input-6-c7ab673569fb>:4: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   raw_eeg = mne.io.read_raw_gdf(r'BCIC_IV_2a/A01E.gdf')

# %%
raw = raw_eeg.copy()
orig_raw = raw_eeg.copy()

raw.plot(duration=5, n_channels=25)
# Out:
# <MNEBrowseFigure size 432x288 with 4 Axes>
# <MNEBrowseFigure size 432x288 with 4 Axes>
